# %%
import pandas as pd

# %%
beneficiaries = pd.read_csv(
    "../data/raw/cms_claims/beneficiary_2023.csv",
    sep="|",
    dtype=str
)

print(beneficiaries.shape)
print(beneficiaries.head())
print(beneficiaries.isna().mean().sort_values(ascending=False).head(20))
# Out:
# (9179, 185)
#            BENE_ID STATE_CODE COUNTY_CD ZIP_CD BENE_BIRTH_DT SEX_IDENT_CD  \
# 0  -10000010254618         01      1500  36109   16-Aug-1999            1
# 1  -10000010254647         01      1410  35756   14-Aug-1990            1
# 2  -10000010254653         01      1400  36801   18-Mar-1982            2
# 3  -10000010254655         01      1360  35071   17-Mar-1958            2
# 4  -10000010254656         01      1360  35216   24-Jul-1999            2
#
#   BENE_RACE_CD ENTLMT_RSN_ORIG ENTLMT_RSN_CURR ESRD_IND  ...  \
# 0            1               1               1        0  ...
# 1            2               1               1        0  ...
# 2            1               1               1        0  ...
# 3            2               0               0        0  ...
# 4            1               1               1        0  ...
#
#   CST_SHR_GRP_CD_03 CST_SHR_GRP_CD_04 CST_SHR_GRP_CD_05 CST_SHR_GRP_CD_06  \
# ...
